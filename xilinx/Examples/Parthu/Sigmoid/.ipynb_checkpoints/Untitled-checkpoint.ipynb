# %%
from pynq import Overlay
from pynq import allocate
import numpy as np
import socket
import os
import time

# Load the bitstream
overlay = Overlay("one.bit")

dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Socket setup
HOST = "0.0.0.0"  # Listen on all interfaces
PORT = 9092       # Port number

total_time = 0  # Initialize total time
file_count = 0  # Counter for files processed

def process_file(conn, addr):
    """Process a single file received from the client."""
    global total_time, file_count  # Declare global variables to modify them

    print(f"Connected by {addr}")
    try:
        while True:
            # Receive 784 bytes of pixel data
            data = conn.recv(784)
            if not data:
                break
            
            # Increment the file counter
            file_count += 1
            
            # Convert the received bytes to a NumPy array
            pixel_data = np.frombuffer(data, dtype=np.uint8)
            
            
            
            # Allocate input buffer and copy data
            input_buffer = allocate(shape=(784,), dtype=np.uint8)
            np.copyto(input_buffer, pixel_data)
            
            # Measure start time
            start_time = time.time()
            
            # Send data to FPGA for processing
            dma.sendchannel.transfer(input_buffer)
            dma.sendchannel.wait()

            # Read the result directly from the zyNet IP
            result_offset = 8  # Adjust based on your IP core
            detected_digit = zynet.read(result_offset)

            # Measure end time and accumulate duration
            end_time = time.time()
            total_time += (end_time - start_time)
            
            # Log the result for the file
            print(f"File #{file_count}: Detected number: {detected_digit}")
            
            # Validate and send the result back to the client
            if 0 <= detected_digit <= 9:  # Assuming valid digits are 0-9
                conn.sendall(bytes([detected_digit]))
            else:
                print(f"Invalid result from FPGA for file #{file_count}: {detected_digit}.")
                conn.sendall(b'\xFF')  # Send error code
    except Exception as e:
        print(f"Error processing file from {addr}: {e}")
    finally:
        conn.close()
        print(f"Connection with {addr} closed.")

# Main server loop
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((HOST, PORT))
    s.listen()
    print(f"Server listening on {HOST}:{PORT}...")

    while True:
        conn, addr = s.accept()
        process_file(conn, addr)
        print(f"Total Time Taken So Far: {total_time:.2f} seconds")
# Out:
# Server listening on 0.0.0.0:9092...
# Connected by ('10.21.236.238', 37430)
# File #1: Detected number: 2
# File #2: Detected number: 2
# File #3: Detected number: 1
# File #4: Detected number: 9
# File #5: Detected number: 1
# File #6: Detected number: 4
# File #7: Detected number: 3
# File #8: Detected number: 1
# File #9: Detected number: 3
# File #10: Detected number: 2
# File #11: Detected number: 8
# File #12: Detected number: 5
# File #13: Detected number: 7
# File #14: Detected number: 9
# File #15: Detected number: 3
# File #16: Detected number: 3
# File #17: Detected number: 5
# File #18: Detected number: 6
# File #19: Detected number: 8
# File #20: Detected number: 8
# File #21: Detected number: 7
# File #22: Detected number: 9
# File #23: Detected number: 6
# File #24: Detected number: 3
# File #25: Detected number: 6
# File #26: Detected number: 1
# File #27: Detected number: 0
# File #28: Detected number: 4
# File #29: Detected number: 0
# File #30: Detected number: 4
# File #31: Detected number: 2
# File #32: Detected number: 7
# File #33: Detected number: 0
# File #34: Detected number: 5
# File #35: Detected number: 2
# File #36: Detected number: 3
# File #37: Detected number: 8
# File #38: Detected number: 4
# File #39: Detected number: 2
# File #40: Detected number: 3
# File #41: Detected number: 3
# File #42: Detected number: 8
# File #43: Detected number: 9
# File #44: Detected number: 3
# File #45: Detected number: 4
# File #46: Detected number: 1
# File #47: Detected number: 9
# File #48: Detected number: 0
# File #49: Detected number: 5
# File #50: Detected number: 1
# File #51: Detected number: 2
# File #52: Detected number: 4
# File #53: Detected number: 5
# File #54: Detected number: 1
# File #55: Detected number: 2
# File #56: Detected number: 6
# File #57: Detected number: 5
# File #58: Detected number: 8
# File #59: Detected number: 5
# File #60: Detected number: 6
# File #61: Detected number: 8
# File #62: Detected number: 7
# File #63: Detected number: 3
# File #64: Detected number: 4
# File #65: Detected number: 2
# File #66: Detected number: 7
# File #67: Detected number: 4
# File #68: Detected number: 2
# File #69: Detected number: 1
# File #70: Detected number: 6
# File #71: Detected number: 6
# File #72: Detected number: 6
# File #73: Detected number: 1
# File #74: Detected number: 5
# File #75: Detected number: 4
# File #76: Detected number: 9
# File #77: Detected number: 1
# File #78: Detected number: 3
# File #79: Detected number: 2
# File #80: Detected number: 5
# File #81: Detected number: 1
# File #82: Detected number: 7
# File #83: Detected number: 2
# File #84: Detected number: 3
# File #85: Detected number: 3
# File #86: Detected number: 3
# File #87: Detected number: 6
# File #88: Detected number: 5
# File #89: Detected number: 9
# File #90: Detected number: 1
# File #91: Detected number: 1
# File #92: Detected number: 9
# File #93: Detected number: 4
# File #94: Detected number: 4
# File #95: Detected number: 9
# File #96: Detected number: 8
# File #97: Detected number: 1
# File #98: Detected number: 7
# File #99: Detected number: 2
# File #100: Detected number: 5
# File #101: Detected number: 1
# File #102: Detected number: 5
# File #103: Detected number: 6
# File #104: Detected number: 8
# File #105: Detected number: 4
# File #106: Detected number: 9
# File #107: Detected number: 9
# File #108: Detected number: 8
# File #109: Detected number: 8
# File #110: Detected number: 8
# File #111: Detected number: 5
# File #112: Detected number: 8
# File #113: Detected number: 1
# File #114: Detected number: 8
# File #115: Detected number: 8
# File #116: Detected number: 6
# File #117: Detected number: 5
# File #118: Detected number: 0
# File #119: Detected number: 4
# File #120: Detected number: 7
# File #121: Detected number: 1
# File #122: Detected number: 0
# File #123: Detected number: 2
# File #124: Detected number: 4
# File #125: Detected number: 5
# File #126: Detected number: 1
# File #127: Detected number: 5
# File #128: Detected number: 2
# File #129: Detected number: 2
# File #130: Detected number: 5
# File #131: Detected number: 0
# File #132: Detected number: 1
# File #133: Detected number: 5
# File #134: Detected number: 8
# File #135: Detected number: 2
# File #136: Detected number: 6
# File #137: Detected number: 8
# File #138: Detected number: 0
# File #139: Detected number: 0
# File #140: Detected number: 7
# File #141: Detected number: 3
# File #142: Detected number: 7
# File #143: Detected number: 3
# File #144: Detected number: 7
# File #145: Detected number: 5
# File #146: Detected number: 1
# File #147: Detected number: 5
# File #148: Detected number: 5
# File #149: Detected number: 7
# File #150: Detected number: 0
# File #151: Detected number: 8
# File #152: Detected number: 8
# File #153: Detected number: 4
# File #154: Detected number: 0
# File #155: Detected number: 3
# File #156: Detected number: 6
# File #157: Detected number: 6
# File #158: Detected number: 0
# File #159: Detected number: 2
# File #160: Detected number: 2
# File #161: Detected number: 1
# File #162: Detected number: 0
# File #163: Detected number: 2
# File #164: Detected number: 4
# File #165: Detected number: 9
# File #166: Detected number: 8
# File #167: Detected number: 1
# File #168: Detected number: 9
# File #169: Detected number: 9
# File #170: Detected number: 3
# File #171: Detected number: 4
# File #172: Detected number: 7
# File #173: Detected number: 9
# File #174: Detected number: 9
# File #175: Detected number: 5
# File #176: Detected number: 1
# File #177: Detected number: 4
# File #178: Detected number: 1
# File #179: Detected number: 1
# File #180: Detected number: 7
# File #181: Detected number: 0
# File #182: Detected number: 2
# File #183: Detected number: 3
# File #184: Detected number: 3
# File #185: Detected number: 3
# File #186: Detected number: 3
# File #187: Detected number: 8
# File #188: Detected number: 4
# File #189: Detected number: 0
# File #190: Detected number: 5
# File #191: Detected number: 3
# File #192: Detected number: 9
# File #193: Detected number: 4
# File #194: Detected number: 6
# File #195: Detected number: 6
# File #196: Detected number: 7
# File #197: Detected number: 9
# File #198: Detected number: 5
# File #199: Detected number: 0
# File #200: Detected number: 4
# File #201: Detected number: 7
# File #202: Detected number: 4
# File #203: Detected number: 8
# File #204: Detected number: 9
# File #205: Detected number: 1
# File #206: Detected number: 8
# File #207: Detected number: 2
# File #208: Detected number: 6
# File #209: Detected number: 7
# File #210: Detected number: 1
# File #211: Detected number: 1
# File #212: Detected number: 0
# File #213: Detected number: 8
# File #214: Detected number: 6
# File #215: Detected number: 9
# File #216: Detected number: 6
# File #217: Detected number: 6
# File #218: Detected number: 7
# File #219: Detected number: 7
# File #220: Detected number: 6
# File #221: Detected number: 0
# File #222: Detected number: 7
# File #223: Detected number: 0
# File #224: Detected number: 6
# File #225: Detected number: 6
# File #226: Detected number: 3
# File #227: Detected number: 0
# File #228: Detected number: 3
# File #229: Detected number: 4
# File #230: Detected number: 0
# File #231: Detected number: 9
# File #232: Detected number: 3
# File #233: Detected number: 0
# File #234: Detected number: 4
# File #235: Detected number: 4
# File #236: Detected number: 0
# File #237: Detected number: 1
# File #238: Detected number: 1
# File #239: Detected number: 3
# File #240: Detected number: 7
# File #241: Detected number: 6
# File #242: Detected number: 0
# File #243: Detected number: 6
# File #244: Detected number: 8
# File #245: Detected number: 9
# File #246: Detected number: 2
# File #247: Detected number: 8
# File #248: Detected number: 1
# File #249: Detected number: 7
# File #250: Detected number: 7
# File #251: Detected number: 8
# File #252: Detected number: 9
# File #253: Detected number: 4
# File #254: Detected number: 4
# File #255: Detected number: 7
# File #256: Detected number: 6
# File #257: Detected number: 9
# File #258: Detected number: 6
# File #259: Detected number: 1
# File #260: Detected number: 0
# File #261: Detected number: 7
# File #262: Detected number: 7
# File #263: Detected number: 0
# File #264: Detected number: 8
# File #265: Detected number: 4
# File #266: Detected number: 5
# File #267: Detected number: 1
# File #268: Detected number: 5
# File #269: Detected number: 4
# File #270: Detected number: 8
# File #271: Detected number: 5
# File #272: Detected number: 0
# File #273: Detected number: 2
# File #274: Detected number: 2
# File #275: Detected number: 6
# File #276: Detected number: 0
# File #277: Detected number: 0
# File #278: Detected number: 2
# File #279: Detected number: 0
# File #280: Detected number: 8
# File #281: Detected number: 0
# File #282: Detected number: 0
# File #283: Detected number: 5
# File #284: Detected number: 5
# File #285: Detected number: 6
# File #286: Detected number: 9
# File #287: Detected number: 0
# File #288: Detected number: 6
# File #289: Detected number: 1
# File #290: Detected number: 9
# File #291: Detected number: 2
# File #292: Detected number: 1
# File #293: Detected number: 6
# File #294: Detected number: 1
# File #295: Detected number: 9
# File #296: Detected number: 2
# File #297: Detected number: 6
# File #298: Detected number: 9
# File #299: Detected number: 6
# File #300: Detected number: 0
# File #301: Detected number: 9
# File #302: Detected number: 4
# File #303: Detected number: 8
# File #304: Detected number: 3
# File #305: Detected number: 9
# File #306: Detected number: 4
# File #307: Detected number: 3
# File #308: Detected number: 8
# File #309: Detected number: 7
# File #310: Detected number: 7
# File #311: Detected number: 4
# File #312: Detected number: 8
# File #313: Detected number: 6
# File #314: Detected number: 9
# File #315: Detected number: 7
# File #316: Detected number: 4
# File #317: Detected number: 0
# File #318: Detected number: 7
# File #319: Detected number: 2
# File #320: Detected number: 3
# File #321: Detected number: 8
# File #322: Detected number: 5
# File #323: Detected number: 9
# File #324: Detected number: 5
# File #325: Detected number: 5
# File #326: Detected number: 7
# File #327: Detected number: 9
# File #328: Detected number: 7
# File #329: Detected number: 1
# File #330: Detected number: 4
# File #331: Detected number: 2
# File #332: Detected number: 6
# File #333: Detected number: 1
# File #334: Detected number: 7
# File #335: Detected number: 1
# File #336: Detected number: 7
# File #337: Detected number: 2
# File #338: Detected number: 7
# File #339: Detected number: 2
# File #340: Detected number: 1
# File #341: Detected number: 8
# File #342: Detected number: 0
# File #343: Detected number: 1
# File #344: Detected number: 3
# File #345: Detected number: 5
# File #346: Detected number: 4
# File #347: Detected number: 7
# File #348: Detected number: 3
# File #349: Detected number: 0
# File #350: Detected number: 4
# File #351: Detected number: 9
# File #352: Detected number: 5
# File #353: Detected number: 8
# File #354: Detected number: 7
# File #355: Detected number: 8
# File #356: Detected number: 6
# File #357: Detected number: 1
# File #358: Detected number: 0
# File #359: Detected number: 5
# File #360: Detected number: 5
# File #361: Detected number: 8
# File #362: Detected number: 4
# File #363: Detected number: 1
# File #364: Detected number: 8
# File #365: Detected number: 2
# File #366: Detected number: 3
# File #367: Detected number: 0
# File #368: Detected number: 9
# File #369: Detected number: 1
# File #370: Detected number: 2
# File #371: Detected number: 9
# File #372: Detected number: 2
# File #373: Detected number: 1
# File #374: Detected number: 6
# File #375: Detected number: 6
# File #376: Detected number: 1
# File #377: Detected number: 6
# File #378: Detected number: 7
# File #379: Detected number: 6
# File #380: Detected number: 8
# File #381: Detected number: 9
# File #382: Detected number: 5
# File #383: Detected number: 4
# File #384: Detected number: 6
# File #385: Detected number: 9
# File #386: Detected number: 8
# File #387: Detected number: 8
# File #388: Detected number: 2
# File #389: Detected number: 7
# File #390: Detected number: 7
# File #391: Detected number: 1
# File #392: Detected number: 8
# File #393: Detected number: 6
# File #394: Detected number: 9
# File #395: Detected number: 5
# File #396: Detected number: 1
# File #397: Detected number: 0
# File #398: Detected number: 6
# File #399: Detected number: 3
# File #400: Detected number: 8
# File #401: Detected number: 2
# File #402: Detected number: 8
# File #403: Detected number: 7
# File #404: Detected number: 4
# File #405: Detected number: 3
# File #406: Detected number: 7
# File #407: Detected number: 9
# File #408: Detected number: 5
# File #409: Detected number: 8
# File #410: Detected number: 2
# File #411: Detected number: 4
# File #412: Detected number: 7
# File #413: Detected number: 6
# File #414: Detected number: 5
# File #415: Detected number: 1
# File #416: Detected number: 6
# File #417: Detected number: 9
# File #418: Detected number: 0
# File #419: Detected number: 0
# File #420: Detected number: 9
# File #421: Detected number: 9
# File #422: Detected number: 7
# File #423: Detected number: 9
# File #424: Detected number: 8
# File #425: Detected number: 8
# File #426: Detected number: 0
# File #427: Detected number: 6
# File #428: Detected number: 9
# File #429: Detected number: 0
# File #430: Detected number: 2
# File #431: Detected number: 5
# File #432: Detected number: 4
# File #433: Detected number: 5
# File #434: Detected number: 4
# File #435: Detected number: 6
# File #436: Detected number: 6
# File #437: Detected number: 3
# File #438: Detected number: 0
# File #439: Detected number: 6
# File #440: Detected number: 9
# File #441: Detected number: 7
# File #442: Detected number: 5
# File #443: Detected number: 1
# File #444: Detected number: 4
# File #445: Detected number: 9
# File #446: Detected number: 7
# File #447: Detected number: 0
# File #448: Detected number: 0
# File #449: Detected number: 7
# File #450: Detected number: 7
# File #451: Detected number: 8
# File #452: Detected number: 6
# File #453: Detected number: 5
# File #454: Detected number: 3
# File #455: Detected number: 4
# File #456: Detected number: 9
# File #457: Detected number: 7
# File #458: Detected number: 1
# File #459: Detected number: 4
# File #460: Detected number: 2
# File #461: Detected number: 9
# File #462: Detected number: 6
# File #463: Detected number: 2
# File #464: Detected number: 4
# File #465: Detected number: 3
# File #466: Detected number: 8
# File #467: Detected number: 8
# File #468: Detected number: 4
# File #469: Detected number: 9
# File #470: Detected number: 1
# File #471: Detected number: 4
# File #472: Detected number: 0
# File #473: Detected number: 1
# File #474: Detected number: 1
# File #475: Detected number: 4
# File #476: Detected number: 2
# File #477: Detected number: 1
# File #478: Detected number: 9
# File #479: Detected number: 6
# File #480: Detected number: 8
# File #481: Detected number: 4
# File #482: Detected number: 2
# File #483: Detected number: 2
# File #484: Detected number: 9
# File #485: Detected number: 9
# File #486: Detected number: 9
# File #487: Detected number: 8
# File #488: Detected number: 6
# File #489: Detected number: 7
# File #490: Detected number: 6
# File #491: Detected number: 9
# File #492: Detected number: 9
# File #493: Detected number: 5
# File #494: Detected number: 2
# File #495: Detected number: 2
# File #496: Detected number: 9
# File #497: Detected number: 3
# File #498: Detected number: 2
# File #499: Detected number: 1
# File #500: Detected number: 9
# File #501: Detected number: 0
# File #502: Detected number: 5
# File #503: Detected number: 8
# File #504: Detected number: 7
# File #505: Detected number: 3
# File #506: Detected number: 2
# File #507: Detected number: 9
# File #508: Detected number: 9
# File #509: Detected number: 4
# File #510: Detected number: 7
# File #511: Detected number: 2
# File #512: Detected number: 6
# File #513: Detected number: 6
# File #514: Detected number: 1
# File #515: Detected number: 0
# File #516: Detected number: 8
# File #517: Detected number: 5
# File #518: Detected number: 3
# File #519: Detected number: 3
# File #520: Detected number: 7
# File #521: Detected number: 3
# File #522: Detected number: 3
# File #523: Detected number: 8
# File #524: Detected number: 4
# File #525: Detected number: 8
# File #526: Detected number: 4
# File #527: Detected number: 6
# File #528: Detected number: 4
# File #529: Detected number: 8
# File #530: Detected number: 4
# File #531: Detected number: 4
# File #532: Detected number: 1
# File #533: Detected number: 6
# File #534: Detected number: 0
# File #535: Detected number: 7
# File #536: Detected number: 9
# File #537: Detected number: 6
# File #538: Detected number: 7
# File #539: Detected number: 8
# File #540: Detected number: 4
# File #541: Detected number: 2
# File #542: Detected number: 5
# File #543: Detected number: 5
# File #544: Detected number: 3
# File #545: Detected number: 3
# File #546: Detected number: 6
# File #547: Detected number: 3
# File #548: Detected number: 6
# File #549: Detected number: 4
# File #550: Detected number: 7
# File #551: Detected number: 3
# File #552: Detected number: 8
# File #553: Detected number: 7
# File #554: Detected number: 8
# File #555: Detected number: 9
# File #556: Detected number: 6
# File #557: Detected number: 1
# File #558: Detected number: 8
# File #559: Detected number: 7
# File #560: Detected number: 9
# File #561: Detected number: 1
# File #562: Detected number: 5
# File #563: Detected number: 4
# File #564: Detected number: 9
# File #565: Detected number: 0
# File #566: Detected number: 8
# File #567: Detected number: 3
# File #568: Detected number: 6
# File #569: Detected number: 1
# File #570: Detected number: 9
# File #571: Detected number: 5
# File #572: Detected number: 8
# File #573: Detected number: 8
# File #574: Detected number: 7
# File #575: Detected number: 5
# File #576: Detected number: 1
# File #577: Detected number: 1
# File #578: Detected number: 3
# File #579: Detected number: 1
# File #580: Detected number: 5
# File #581: Detected number: 2
# File #582: Detected number: 6
# File #583: Detected number: 4
# File #584: Detected number: 4
# File #585: Detected number: 0
# File #586: Detected number: 3
# File #587: Detected number: 9
# File #588: Detected number: 5
# File #589: Detected number: 2
# File #590: Detected number: 0
# File #591: Detected number: 8
# File #592: Detected number: 6
# File #593: Detected number: 0
# File #594: Detected number: 0
# File #595: Detected number: 1
# File #596: Detected number: 1
# File #597: Detected number: 0
# File #598: Detected number: 9
# File #599: Detected number: 8
# File #600: Detected number: 2
# File #601: Detected number: 3
# File #602: Detected number: 1
# File #603: Detected number: 7
# File #604: Detected number: 3
# File #605: Detected number: 7
# File #606: Detected number: 5
# File #607: Detected number: 3
# File #608: Detected number: 1
# File #609: Detected number: 8
# File #610: Detected number: 0
# File #611: Detected number: 6
# File #612: Detected number: 4
# File #613: Detected number: 7
# File #614: Detected number: 5
# File #615: Detected number: 3
# File #616: Detected number: 1
# File #617: Detected number: 2
# File #618: Detected number: 2
# File #619: Detected number: 8
# File #620: Detected number: 8
# File #621: Detected number: 5
# File #622: Detected number: 6
# File #623: Detected number: 3
# File #624: Detected number: 3
# File #625: Detected number: 8
# File #626: Detected number: 4
# File #627: Detected number: 2
# File #628: Detected number: 6
# File #629: Detected number: 0
# File #630: Detected number: 3
# File #631: Detected number: 2
# File #632: Detected number: 0
# File #633: Detected number: 9
# File #634: Detected number: 0
# File #635: Detected number: 2
# File #636: Detected number: 7
# File #637: Detected number: 7
# File #638: Detected number: 9
# File #639: Detected number: 5
# File #640: Detected number: 7
# File #641: Detected number: 4
# File #642: Detected number: 0
# File #643: Detected number: 4
# File #644: Detected number: 7
# File #645: Detected number: 8
# File #646: Detected number: 6
# File #647: Detected number: 1
# File #648: Detected number: 2
# File #649: Detected number: 9
# File #650: Detected number: 3
# File #651: Detected number: 4
# File #652: Detected number: 5
# File #653: Detected number: 3
# File #654: Detected number: 3
# File #655: Detected number: 6
# File #656: Detected number: 5
# File #657: Detected number: 0
# File #658: Detected number: 1
# File #659: Detected number: 2
# File #660: Detected number: 5
# File #661: Detected number: 5
# File #662: Detected number: 9
# File #663: Detected number: 4
# File #664: Detected number: 0
# File #665: Detected number: 4
# File #666: Detected number: 0
# File #667: Detected number: 8
# File #668: Detected number: 6
# File #669: Detected number: 7
# File #670: Detected number: 0
# File #671: Detected number: 1
# File #672: Detected number: 0
# File #673: Detected number: 6
# File #674: Detected number: 7
# File #675: Detected number: 8
# File #676: Detected number: 5
# File #677: Detected number: 2
# File #678: Detected number: 2
# File #679: Detected number: 3
# File #680: Detected number: 8
# File #681: Detected number: 6
# File #682: Detected number: 0
# File #683: Detected number: 0
# File #684: Detected number: 5
# File #685: Detected number: 7
# File #686: Detected number: 9
# File #687: Detected number: 6
# File #688: Detected number: 0
# File #689: Detected number: 2
# File #690: Detected number: 5
# File #691: Detected number: 2
# File #692: Detected number: 3
# File #693: Detected number: 8
# File #694: Detected number: 4
# File #695: Detected number: 5
# File #696: Detected number: 6
# File #697: Detected number: 9
# File #698: Detected number: 5
# File #699: Detected number: 2
# File #700: Detected number: 1
# File #701: Detected number: 3
# File #702: Detected number: 3
# File #703: Detected number: 3
# File #704: Detected number: 5
# File #705: Detected number: 3
# File #706: Detected number: 8
# File #707: Detected number: 5
# File #708: Detected number: 4
# File #709: Detected number: 8
# File #710: Detected number: 9
# File #711: Detected number: 6
# File #712: Detected number: 5
# File #713: Detected number: 7
# File #714: Detected number: 3
# File #715: Detected number: 9
# File #716: Detected number: 2
# File #717: Detected number: 9
# File #718: Detected number: 2
# File #719: Detected number: 0
# File #720: Detected number: 4
# File #721: Detected number: 6
# File #722: Detected number: 3
# File #723: Detected number: 9
# File #724: Detected number: 0
# File #725: Detected number: 6
# File #726: Detected number: 4
# File #727: Detected number: 6
# File #728: Detected number: 1
# File #729: Detected number: 2
# File #730: Detected number: 5
# File #731: Detected number: 7
# File #732: Detected number: 6
# File #733: Detected number: 4
# File #734: Detected number: 4
# File #735: Detected number: 7
# File #736: Detected number: 5
# File #737: Detected number: 6
# File #738: Detected number: 8
# File #739: Detected number: 8
# File #740: Detected number: 5
# File #741: Detected number: 8
# File #742: Detected number: 2
# File #743: Detected number: 2
# File #744: Detected number: 5
# File #745: Detected number: 1
# File #746: Detected number: 3
# File #747: Detected number: 4
# File #748: Detected number: 6
# File #749: Detected number: 2
# File #750: Detected number: 9
# File #751: Detected number: 9
# File #752: Detected number: 6
# File #753: Detected number: 2
# File #754: Detected number: 0
# File #755: Detected number: 0
# File #756: Detected number: 8
# File #757: Detected number: 5
# File #758: Detected number: 7
# File #759: Detected number: 2
# File #760: Detected number: 9
# File #761: Detected number: 8
# File #762: Detected number: 4
# File #763: Detected number: 1
# File #764: Detected number: 9
# File #765: Detected number: 3
# File #766: Detected number: 1
# File #767: Detected number: 4
# File #768: Detected number: 4
# File #769: Detected number: 4
# File #770: Detected number: 3
# File #771: Detected number: 1
# File #772: Detected number: 2
# File #773: Detected number: 5
# File #774: Detected number: 0
# File #775: Detected number: 5
# File #776: Detected number: 2
# File #777: Detected number: 8
# File #778: Detected number: 6
# File #779: Detected number: 1
# File #780: Detected number: 6
# File #781: Detected number: 8
# File #782: Detected number: 1
# File #783: Detected number: 2
# File #784: Detected number: 5
# File #785: Detected number: 8
# File #786: Detected number: 1
# File #787: Detected number: 2
# File #788: Detected number: 8
# File #789: Detected number: 0
# File #790: Detected number: 0
# File #791: Detected number: 2
# File #792: Detected number: 9
# File #793: Detected number: 7
# File #794: Detected number: 2
# File #795: Detected number: 3
# File #796: Detected number: 4
# File #797: Detected number: 5
# File #798: Detected number: 5
# File #799: Detected number: 9
# File #800: Detected number: 3
# File #801: Detected number: 6
# File #802: Detected number: 3
# File #803: Detected number: 5
# File #804: Detected number: 4
# File #805: Detected number: 5
# File #806: Detected number: 8
# File #807: Detected number: 7
# File #808: Detected number: 3
# File #809: Detected number: 0
# File #810: Detected number: 7
# File #811: Detected number: 1
# File #812: Detected number: 2
# File #813: Detected number: 9
# File #814: Detected number: 9
# File #815: Detected number: 1
# File #816: Detected number: 1
# File #817: Detected number: 4
# File #818: Detected number: 2
# File #819: Detected number: 3
# File #820: Detected number: 4
# File #821: Detected number: 8
# File #822: Detected number: 7
# File #823: Detected number: 8
# File #824: Detected number: 6
# File #825: Detected number: 8
# File #826: Detected number: 3
# File #827: Detected number: 2
# File #828: Detected number: 3
# File #829: Detected number: 1
# File #830: Detected number: 3
# File #831: Detected number: 4
# File #832: Detected number: 6
# File #833: Detected number: 1
# File #834: Detected number: 8
# File #835: Detected number: 8
# File #836: Detected number: 3
# File #837: Detected number: 5
# File #838: Detected number: 5
# File #839: Detected number: 0
# File #840: Detected number: 1
# File #841: Detected number: 6
# File #842: Detected number: 4
# File #843: Detected number: 6
# File #844: Detected number: 1
# File #845: Detected number: 4
# File #846: Detected number: 4
# File #847: Detected number: 1
# File #848: Detected number: 4
# File #849: Detected number: 0
# File #850: Detected number: 3
# File #851: Detected number: 2
# File #852: Detected number: 0
# File #853: Detected number: 2
# File #854: Detected number: 6
# File #855: Detected number: 6
# File #856: Detected number: 3
# File #857: Detected number: 9
# File #858: Detected number: 7
# File #859: Detected number: 4
# File #860: Detected number: 2
# File #861: Detected number: 2
# File #862: Detected number: 7
# File #863: Detected number: 2
# File #864: Detected number: 2
# File #865: Detected number: 1
# File #866: Detected number: 3
# File #867: Detected number: 6
# File #868: Detected number: 7
# File #869: Detected number: 9
# File #870: Detected number: 1
# File #871: Detected number: 0
# File #872: Detected number: 8
# File #873: Detected number: 9
# File #874: Detected number: 0
# File #875: Detected number: 6
# File #876: Detected number: 3
# File #877: Detected number: 5
# File #878: Detected number: 2
# File #879: Detected number: 1
# File #880: Detected number: 8
# File #881: Detected number: 1
# File #882: Detected number: 1
# File #883: Detected number: 0
# File #884: Detected number: 1
# File #885: Detected number: 7
# File #886: Detected number: 7
# File #887: Detected number: 0
# File #888: Detected number: 6
# File #889: Detected number: 7
# File #890: Detected number: 8
# File #891: Detected number: 9
# File #892: Detected number: 9
# File #893: Detected number: 7
# File #894: Detected number: 2
# File #895: Detected number: 8
# File #896: Detected number: 5
# File #897: Detected number: 2
# File #898: Detected number: 7
# File #899: Detected number: 8
# File #900: Detected number: 9
# File #901: Detected number: 7
# File #902: Detected number: 8
# File #903: Detected number: 5
# File #904: Detected number: 7
# File #905: Detected number: 5
# File #906: Detected number: 1
# File #907: Detected number: 8
# File #908: Detected number: 6
# File #909: Detected number: 9
# File #910: Detected number: 0
# File #911: Detected number: 9
# File #912: Detected number: 0
# File #913: Detected number: 3
# File #914: Detected number: 0
# File #915: Detected number: 1
# File #916: Detected number: 1
# File #917: Detected number: 0
# File #918: Detected number: 3
# File #919: Detected number: 4
# File #920: Detected number: 2
# File #921: Detected number: 5
# File #922: Detected number: 4
# File #923: Detected number: 0
# File #924: Detected number: 2
# File #925: Detected number: 3
# File #926: Detected number: 8
# File #927: Detected number: 3
# File #928: Detected number: 5
# File #929: Detected number: 6
# File #930: Detected number: 0
# File #931: Detected number: 7
# File #932: Detected number: 8
# File #933: Detected number: 6
# File #934: Detected number: 3
# File #935: Detected number: 6
# File #936: Detected number: 6
# File #937: Detected number: 0
# File #938: Detected number: 6
# File #939: Detected number: 5
# File #940: Detected number: 4
# File #941: Detected number: 6
# File #942: Detected number: 9
# File #943: Detected number: 7
# File #944: Detected number: 2
# File #945: Detected number: 9
# File #946: Detected number: 9
# File #947: Detected number: 0
# File #948: Detected number: 9
# File #949: Detected number: 6
# File #950: Detected number: 9
# File #951: Detected number: 3
# File #952: Detected number: 8
# File #953: Detected number: 3
# File #954: Detected number: 8
# File #955: Detected number: 0
# File #956: Detected number: 8
# File #957: Detected number: 6
# File #958: Detected number: 6
# File #959: Detected number: 2
# File #960: Detected number: 4
# File #961: Detected number: 9
# File #962: Detected number: 0
# File #963: Detected number: 0
# File #964: Detected number: 0
# File #965: Detected number: 0
# File #966: Detected number: 1
# File #967: Detected number: 7
# File #968: Detected number: 2
# File #969: Detected number: 4
# File #970: Detected number: 1
# File #971: Detected number: 8
# File #972: Detected number: 1
# File #973: Detected number: 9
# File #974: Detected number: 5
# File #975: Detected number: 0
# File #976: Detected number: 1
# File #977: Detected number: 7
# File #978: Detected number: 8
# File #979: Detected number: 3
# File #980: Detected number: 8
# File #981: Detected number: 7
# File #982: Detected number: 4
# File #983: Detected number: 0
# File #984: Detected number: 5
# File #985: Detected number: 4
# File #986: Detected number: 4
# File #987: Detected number: 1
# File #988: Detected number: 7
# File #989: Detected number: 3
# File #990: Detected number: 6
# File #991: Detected number: 6
# File #992: Detected number: 7
# File #993: Detected number: 3
# File #994: Detected number: 3
# File #995: Detected number: 4
# File #996: Detected number: 8
# File #997: Detected number: 3
# File #998: Detected number: 6
# File #999: Detected number: 6
# File #1000: Detected number: 8
# File #1001: Detected number: 7
# File #1002: Detected number: 8
# File #1003: Detected number: 9
# File #1004: Detected number: 3
# File #1005: Detected number: 2
# File #1006: Detected number: 4
# File #1007: Detected number: 9
# File #1008: Detected number: 0
# File #1009: Detected number: 6
# File #1010: Detected number: 6
# File #1011: Detected number: 8
# File #1012: Detected number: 3
# File #1013: Detected number: 6
# File #1014: Detected number: 7
# File #1015: Detected number: 2
# File #1016: Detected number: 9
# File #1017: Detected number: 1
# File #1018: Detected number: 3
# File #1019: Detected number: 0
# File #1020: Detected number: 1
# File #1021: Detected number: 9
# File #1022: Detected number: 2
# File #1023: Detected number: 2
# File #1024: Detected number: 6
# File #1025: Detected number: 7
# File #1026: Detected number: 2
# File #1027: Detected number: 5
# File #1028: Detected number: 2
# File #1029: Detected number: 3
# File #1030: Detected number: 6
# File #1031: Detected number: 3
# File #1032: Detected number: 3
# File #1033: Detected number: 3
# File #1034: Detected number: 7
# File #1035: Detected number: 2
# File #1036: Detected number: 2
# File #1037: Detected number: 7
# File #1038: Detected number: 8
# File #1039: Detected number: 6
# File #1040: Detected number: 1
# File #1041: Detected number: 6
# File #1042: Detected number: 5
# File #1043: Detected number: 1
# File #1044: Detected number: 2
# File #1045: Detected number: 6
# File #1046: Detected number: 0
# File #1047: Detected number: 7
# File #1048: Detected number: 4
# File #1049: Detected number: 4
# File #1050: Detected number: 6
# File #1051: Detected number: 7
# File #1052: Detected number: 9
# File #1053: Detected number: 4
# File #1054: Detected number: 8
# File #1055: Detected number: 2
# File #1056: Detected number: 4
# File #1057: Detected number: 7
# File #1058: Detected number: 9
# File #1059: Detected number: 0
# File #1060: Detected number: 4
# File #1061: Detected number: 7
# File #1062: Detected number: 3
# File #1063: Detected number: 2
# File #1064: Detected number: 5
# File #1065: Detected number: 3
# File #1066: Detected number: 3
# File #1067: Detected number: 6
# File #1068: Detected number: 5
# File #1069: Detected number: 2
# File #1070: Detected number: 4
# File #1071: Detected number: 8
# File #1072: Detected number: 0
# File #1073: Detected number: 0
# File #1074: Detected number: 2
# File #1075: Detected number: 5
# File #1076: Detected number: 0
# File #1077: Detected number: 3
# File #1078: Detected number: 1
# File #1079: Detected number: 0
# File #1080: Detected number: 8
# File #1081: Detected number: 0
# File #1082: Detected number: 5
# File #1083: Detected number: 1
# File #1084: Detected number: 1
# File #1085: Detected number: 8
# File #1086: Detected number: 9
# File #1087: Detected number: 9
# File #1088: Detected number: 8
# File #1089: Detected number: 0
# File #1090: Detected number: 9
# File #1091: Detected number: 0
# File #1092: Detected number: 0
# File #1093: Detected number: 9
# File #1094: Detected number: 8
# File #1095: Detected number: 5
# File #1096: Detected number: 1
# File #1097: Detected number: 4
# File #1098: Detected number: 6
# File #1099: Detected number: 7
# File #1100: Detected number: 3
# File #1101: Detected number: 7
# File #1102: Detected number: 1
# File #1103: Detected number: 3
# File #1104: Detected number: 6
# File #1105: Detected number: 0
# File #1106: Detected number: 3
# File #1107: Detected number: 4
# File #1108: Detected number: 0
# File #1109: Detected number: 0
# File #1110: Detected number: 8
# File #1111: Detected number: 4
# File #1112: Detected number: 4
# File #1113: Detected number: 0
# File #1114: Detected number: 3
# File #1115: Detected number: 8
# File #1116: Detected number: 0
# File #1117: Detected number: 3
# File #1118: Detected number: 9
# File #1119: Detected number: 5
# File #1120: Detected number: 7
# File #1121: Detected number: 6
# File #1122: Detected number: 7
# File #1123: Detected number: 4
# File #1124: Detected number: 0
# File #1125: Detected number: 0
# File #1126: Detected number: 4
# File #1127: Detected number: 4
# File #1128: Detected number: 6
# File #1129: Detected number: 8
# File #1130: Detected number: 1
# File #1131: Detected number: 2
# File #1132: Detected number: 7
# File #1133: Detected number: 7
# File #1134: Detected number: 1
# File #1135: Detected number: 9
# File #1136: Detected number: 6
# File #1137: Detected number: 6
# File #1138: Detected number: 9
# File #1139: Detected number: 9
# File #1140: Detected number: 8
# File #1141: Detected number: 0
# File #1142: Detected number: 8
# File #1143: Detected number: 7
# File #1144: Detected number: 0
# File #1145: Detected number: 1
# File #1146: Detected number: 5
# File #1147: Detected number: 6
# File #1148: Detected number: 0
# File #1149: Detected number: 5
# File #1150: Detected number: 1
# File #1151: Detected number: 3
# File #1152: Detected number: 5
# File #1153: Detected number: 4
# File #1154: Detected number: 2
# File #1155: Detected number: 4
# File #1156: Detected number: 0
# File #1157: Detected number: 5
# File #1158: Detected number: 4
# File #1159: Detected number: 4
# File #1160: Detected number: 7
# File #1161: Detected number: 7
# File #1162: Detected number: 2
# File #1163: Detected number: 8
# File #1164: Detected number: 1
# File #1165: Detected number: 1
# File #1166: Detected number: 6
# File #1167: Detected number: 9
# File #1168: Detected number: 4
# File #1169: Detected number: 7
# File #1170: Detected number: 4
# File #1171: Detected number: 9
# File #1172: Detected number: 8
# File #1173: Detected number: 0
# File #1174: Detected number: 9
# File #1175: Detected number: 3
# File #1176: Detected number: 8
# File #1177: Detected number: 2
# File #1178: Detected number: 5
# File #1179: Detected number: 8
# File #1180: Detected number: 1
# File #1181: Detected number: 1
# File #1182: Detected number: 1
# File #1183: Detected number: 6
# File #1184: Detected number: 0
# File #1185: Detected number: 4
# File #1186: Detected number: 3
# File #1187: Detected number: 2
# File #1188: Detected number: 5
# File #1189: Detected number: 1
# File #1190: Detected number: 1
# File #1191: Detected number: 7
# File #1192: Detected number: 9
# File #1193: Detected number: 7
# File #1194: Detected number: 8
# File #1195: Detected number: 3
# File #1196: Detected number: 8
# File #1197: Detected number: 8
# File #1198: Detected number: 4
# File #1199: Detected number: 5
# File #1200: Detected number: 6
# File #1201: Detected number: 8
# File #1202: Detected number: 9
# File #1203: Detected number: 5
# File #1204: Detected number: 8
# File #1205: Detected number: 6
# File #1206: Detected number: 2
# File #1207: Detected number: 7
# File #1208: Detected number: 7
# File #1209: Detected number: 5
# File #1210: Detected number: 0
# File #1211: Detected number: 5
# File #1212: Detected number: 7
# File #1213: Detected number: 1
# File #1214: Detected number: 4
# File #1215: Detected number: 7
# File #1216: Detected number: 1
# File #1217: Detected number: 7
# File #1218: Detected number: 1
# File #1219: Detected number: 2
# File #1220: Detected number: 3
# File #1221: Detected number: 3
# File #1222: Detected number: 2
# File #1223: Detected number: 8
# File #1224: Detected number: 7
# File #1225: Detected number: 9
# File #1226: Detected number: 3
# File #1227: Detected number: 6
# File #1228: Detected number: 9
# File #1229: Detected number: 1
# File #1230: Detected number: 8
# File #1231: Detected number: 5
# File #1232: Detected number: 7
# File #1233: Detected number: 2
# File #1234: Detected number: 1
# File #1235: Detected number: 3
# File #1236: Detected number: 8
# File #1237: Detected number: 9
# File #1238: Detected number: 5
# File #1239: Detected number: 1
# File #1240: Detected number: 1
# File #1241: Detected number: 0
# File #1242: Detected number: 4
# File #1243: Detected number: 8
# File #1244: Detected number: 8
# File #1245: Detected number: 3
# File #1246: Detected number: 6
# File #1247: Detected number: 1
# File #1248: Detected number: 1
# File #1249: Detected number: 2
# File #1250: Detected number: 5
# File #1251: Detected number: 5
# File #1252: Detected number: 1
# File #1253: Detected number: 0
# File #1254: Detected number: 9
# File #1255: Detected number: 4
# File #1256: Detected number: 2
# File #1257: Detected number: 1
# File #1258: Detected number: 7
# File #1259: Detected number: 8
# File #1260: Detected number: 1
# File #1261: Detected number: 4
# File #1262: Detected number: 4
# File #1263: Detected number: 8
# File #1264: Detected number: 7
# File #1265: Detected number: 8
# File #1266: Detected number: 1
# File #1267: Detected number: 9
# File #1268: Detected number: 0
# File #1269: Detected number: 3
# File #1270: Detected number: 9
# File #1271: Detected number: 1
# File #1272: Detected number: 6
# File #1273: Detected number: 1
# File #1274: Detected number: 9
# File #1275: Detected number: 7
# File #1276: Detected number: 7
# File #1277: Detected number: 2
# File #1278: Detected number: 4
# File #1279: Detected number: 2
# File #1280: Detected number: 8
# File #1281: Detected number: 5
# File #1282: Detected number: 6
# File #1283: Detected number: 1
# File #1284: Detected number: 0
# File #1285: Detected number: 7
# File #1286: Detected number: 7
# File #1287: Detected number: 9
# File #1288: Detected number: 9
# File #1289: Detected number: 1
# File #1290: Detected number: 3
# File #1291: Detected number: 9
# File #1292: Detected number: 3
# File #1293: Detected number: 0
# File #1294: Detected number: 8
# File #1295: Detected number: 1
# File #1296: Detected number: 0
# File #1297: Detected number: 2
# File #1298: Detected number: 0
# File #1299: Detected number: 5
# File #1300: Detected number: 8
# File #1301: Detected number: 2
# File #1302: Detected number: 6
# File #1303: Detected number: 8
# File #1304: Detected number: 8
# File #1305: Detected number: 2
# File #1306: Detected number: 5
# File #1307: Detected number: 9
# File #1308: Detected number: 7
# File #1309: Detected number: 5
# File #1310: Detected number: 3
# File #1311: Detected number: 2
# File #1312: Detected number: 2
# File #1313: Detected number: 5
# File #1314: Detected number: 3
# File #1315: Detected number: 3
# File #1316: Detected number: 9
# File #1317: Detected number: 5
# File #1318: Detected number: 2
# File #1319: Detected number: 4
# File #1320: Detected number: 5
# File #1321: Detected number: 1
# File #1322: Detected number: 5
# File #1323: Detected number: 4
# File #1324: Detected number: 2
# File #1325: Detected number: 2
# File #1326: Detected number: 8
# File #1327: Detected number: 6
# File #1328: Detected number: 6
# File #1329: Detected number: 8
# File #1330: Detected number: 0
# File #1331: Detected number: 5
# File #1332: Detected number: 7
# File #1333: Detected number: 1
# File #1334: Detected number: 5
# File #1335: Detected number: 5
# File #1336: Detected number: 3
# File #1337: Detected number: 0
# File #1338: Detected number: 3
# File #1339: Detected number: 8
# File #1340: Detected number: 8
# File #1341: Detected number: 9
# File #1342: Detected number: 6
# File #1343: Detected number: 7
# File #1344: Detected number: 0
# File #1345: Detected number: 2
# File #1346: Detected number: 5
# File #1347: Detected number: 2
# File #1348: Detected number: 8
# File #1349: Detected number: 0
# File #1350: Detected number: 9
# File #1351: Detected number: 2
# File #1352: Detected number: 2
# File #1353: Detected number: 2
# File #1354: Detected number: 6
# File #1355: Detected number: 3
# File #1356: Detected number: 0
# File #1357: Detected number: 2
# File #1358: Detected number: 4
# File #1359: Detected number: 9
# File #1360: Detected number: 7
# File #1361: Detected number: 2
# File #1362: Detected number: 4
# File #1363: Detected number: 8
# File #1364: Detected number: 8
# File #1365: Detected number: 5
# File #1366: Detected number: 2
# File #1367: Detected number: 1
# File #1368: Detected number: 4
# File #1369: Detected number: 4
# File #1370: Detected number: 0
# File #1371: Detected number: 4
# File #1372: Detected number: 8
# File #1373: Detected number: 1
# File #1374: Detected number: 8
# File #1375: Detected number: 5
# File #1376: Detected number: 3
# File #1377: Detected number: 6
# File #1378: Detected number: 6
# File #1379: Detected number: 0
# File #1380: Detected number: 7
# File #1381: Detected number: 2
# File #1382: Detected number: 1
# File #1383: Detected number: 0
# File #1384: Detected number: 5
# File #1385: Detected number: 2
# File #1386: Detected number: 3
# File #1387: Detected number: 7
# File #1388: Detected number: 8
# File #1389: Detected number: 7
# File #1390: Detected number: 3
# File #1391: Detected number: 5
# File #1392: Detected number: 4
# File #1393: Detected number: 0
# File #1394: Detected number: 1
# File #1395: Detected number: 8
# File #1396: Detected number: 3
# File #1397: Detected number: 2
# File #1398: Detected number: 5
# File #1399: Detected number: 5
# File #1400: Detected number: 6
# File #1401: Detected number: 8
# File #1402: Detected number: 5
# File #1403: Detected number: 6
# File #1404: Detected number: 0
# File #1405: Detected number: 6
# File #1406: Detected number: 8
# File #1407: Detected number: 2
# File #1408: Detected number: 4
# File #1409: Detected number: 9
# File #1410: Detected number: 7
# File #1411: Detected number: 8
# File #1412: Detected number: 6
# File #1413: Detected number: 9
# File #1414: Detected number: 4
# File #1415: Detected number: 0
# File #1416: Detected number: 6
# File #1417: Detected number: 6
# File #1418: Detected number: 2
# File #1419: Detected number: 4
# File #1420: Detected number: 5
# File #1421: Detected number: 8
# File #1422: Detected number: 4
# File #1423: Detected number: 3
# File #1424: Detected number: 1
# File #1425: Detected number: 4
# File #1426: Detected number: 0
# File #1427: Detected number: 5
# File #1428: Detected number: 4
# File #1429: Detected number: 3
# File #1430: Detected number: 4
# File #1431: Detected number: 1
# File #1432: Detected number: 3
# File #1433: Detected number: 9
# File #1434: Detected number: 5
# File #1435: Detected number: 3
# File #1436: Detected number: 4
# File #1437: Detected number: 2
# File #1438: Detected number: 3
# File #1439: Detected number: 8
# File #1440: Detected number: 2
# File #1441: Detected number: 2
# File #1442: Detected number: 0
# File #1443: Detected number: 7
# File #1444: Detected number: 3
# File #1445: Detected number: 3
# File #1446: Detected number: 2
# File #1447: Detected number: 9
# File #1448: Detected number: 9
# File #1449: Detected number: 9
# File #1450: Detected number: 4
# File #1451: Detected number: 9
# File #1452: Detected number: 9
# File #1453: Detected number: 2
# File #1454: Detected number: 5
# File #1455: Detected number: 4
# File #1456: Detected number: 8
# File #1457: Detected number: 3
# File #1458: Detected number: 1
# File #1459: Detected number: 0
# File #1460: Detected number: 4
# File #1461: Detected number: 3
# File #1462: Detected number: 9
# File #1463: Detected number: 3
# File #1464: Detected number: 1
# File #1465: Detected number: 1
# File #1466: Detected number: 7
# File #1467: Detected number: 3
# File #1468: Detected number: 8
# File #1469: Detected number: 4
# File #1470: Detected number: 8
# File #1471: Detected number: 8
# File #1472: Detected number: 8
# File #1473: Detected number: 1
# File #1474: Detected number: 4
# File #1475: Detected number: 4
# File #1476: Detected number: 5
# File #1477: Detected number: 9
# File #1478: Detected number: 4
# File #1479: Detected number: 5
# File #1480: Detected number: 6
# File #1481: Detected number: 6
# File #1482: Detected number: 4
# File #1483: Detected number: 9
# File #1484: Detected number: 3
# File #1485: Detected number: 3
# File #1486: Detected number: 9
# File #1487: Detected number: 7
# File #1488: Detected number: 2
# File #1489: Detected number: 1
# File #1490: Detected number: 2
# File #1491: Detected number: 4
# File #1492: Detected number: 1
# File #1493: Detected number: 4
# File #1494: Detected number: 2
# File #1495: Detected number: 2
# File #1496: Detected number: 7
# File #1497: Detected number: 8
# File #1498: Detected number: 3
# File #1499: Detected number: 8
# File #1500: Detected number: 7
# File #1501: Detected number: 7
# File #1502: Detected number: 4
# File #1503: Detected number: 1
# File #1504: Detected number: 5
# File #1505: Detected number: 8
# File #1506: Detected number: 8
# File #1507: Detected number: 7
# File #1508: Detected number: 4
# File #1509: Detected number: 8
# File #1510: Detected number: 6
# File #1511: Detected number: 4
# File #1512: Detected number: 3
# File #1513: Detected number: 4
# File #1514: Detected number: 5
# File #1515: Detected number: 7
# File #1516: Detected number: 5
# File #1517: Detected number: 6
# File #1518: Detected number: 6
# File #1519: Detected number: 9
# File #1520: Detected number: 2
# File #1521: Detected number: 9
# File #1522: Detected number: 6
# File #1523: Detected number: 7
# File #1524: Detected number: 6
# File #1525: Detected number: 6
# File #1526: Detected number: 6
# File #1527: Detected number: 7
# File #1528: Detected number: 4
# File #1529: Detected number: 6
# File #1530: Detected number: 0
# File #1531: Detected number: 9
# File #1532: Detected number: 6
# File #1533: Detected number: 4
# File #1534: Detected number: 3
# File #1535: Detected number: 0
# File #1536: Detected number: 4
# File #1537: Detected number: 7
# File #1538: Detected number: 6
# File #1539: Detected number: 7
# File #1540: Detected number: 4
# File #1541: Detected number: 6
# File #1542: Detected number: 0
# File #1543: Detected number: 0
# File #1544: Detected number: 2
# File #1545: Detected number: 7
# File #1546: Detected number: 3
# File #1547: Detected number: 7
# File #1548: Detected number: 1
# File #1549: Detected number: 2
# File #1550: Detected number: 3
# File #1551: Detected number: 8
# File #1552: Detected number: 7
# File #1553: Detected number: 6
# File #1554: Detected number: 5
# File #1555: Detected number: 2
# File #1556: Detected number: 7
# File #1557: Detected number: 3
# File #1558: Detected number: 5
# File #1559: Detected number: 3
# File #1560: Detected number: 0
# File #1561: Detected number: 1
# File #1562: Detected number: 5
# File #1563: Detected number: 8
# File #1564: Detected number: 7
# File #1565: Detected number: 3
# File #1566: Detected number: 5
# File #1567: Detected number: 1
# File #1568: Detected number: 7
# File #1569: Detected number: 9
# File #1570: Detected number: 3
# File #1571: Detected number: 2
# File #1572: Detected number: 3
# File #1573: Detected number: 7
# File #1574: Detected number: 4
# File #1575: Detected number: 0
# File #1576: Detected number: 4
# File #1577: Detected number: 5
# File #1578: Detected number: 3
# File #1579: Detected number: 0
# File #1580: Detected number: 7
# File #1581: Detected number: 0
# ...
# File #9488: Detected number: 1
# File #9489: Detected number: 9
# File #9490: Detected number: 9
# File #9491: Detected number: 3
# File #9492: Detected number: 6
# File #9493: Detected number: 8
# File #9494: Detected number: 6
# File #9495: Detected number: 8
# File #9496: Detected number: 6
# File #9497: Detected number: 8
# File #9498: Detected number: 9
# File #9499: Detected number: 1
# File #9500: Detected number: 9
# File #9501: Detected number: 3
# File #9502: Detected number: 6
# File #9503: Detected number: 7
# File #9504: Detected number: 3
# File #9505: Detected number: 8
# File #9506: Detected number: 5
# File #9507: Detected number: 8
# File #9508: Detected number: 7
# File #9509: Detected number: 9
# File #9510: Detected number: 2
# File #9511: Detected number: 9
# File #9512: Detected number: 7
# File #9513: Detected number: 1
# File #9514: Detected number: 1
# File #9515: Detected number: 1
# File #9516: Detected number: 6
# File #9517: Detected number: 9
# File #9518: Detected number: 7
# File #9519: Detected number: 0
# File #9520: Detected number: 3
# File #9521: Detected number: 8
# File #9522: Detected number: 1
# File #9523: Detected number: 2
# File #9524: Detected number: 1
# File #9525: Detected number: 8
# File #9526: Detected number: 4
# File #9527: Detected number: 0
# File #9528: Detected number: 9
# File #9529: Detected number: 7
# File #9530: Detected number: 9
# File #9531: Detected number: 9
# File #9532: Detected number: 9
# File #9533: Detected number: 2
# File #9534: Detected number: 7
# File #9535: Detected number: 7
# File #9536: Detected number: 7
# File #9537: Detected number: 9
# File #9538: Detected number: 9
# File #9539: Detected number: 6
# File #9540: Detected number: 1
# File #9541: Detected number: 3
# File #9542: Detected number: 1
# File #9543: Detected number: 9
# File #9544: Detected number: 7
# File #9545: Detected number: 1
# File #9546: Detected number: 6
# File #9547: Detected number: 5
# File #9548: Detected number: 1
# File #9549: Detected number: 2
# File #9550: Detected number: 7
# File #9551: Detected number: 9
# File #9552: Detected number: 5
# File #9553: Detected number: 1
# File #9554: Detected number: 8
# File #9555: Detected number: 6
# File #9556: Detected number: 7
# File #9557: Detected number: 8
# File #9558: Detected number: 2
# File #9559: Detected number: 7
# File #9560: Detected number: 2
# File #9561: Detected number: 8
# File #9562: Detected number: 7
# File #9563: Detected number: 1
# File #9564: Detected number: 3
# File #9565: Detected number: 7
# File #9566: Detected number: 8
# File #9567: Detected number: 8
# File #9568: Detected number: 3
# File #9569: Detected number: 2
# File #9570: Detected number: 1
# File #9571: Detected number: 4
# File #9572: Detected number: 5
# File #9573: Detected number: 0
# File #9574: Detected number: 7
# File #9575: Detected number: 4
# File #9576: Detected number: 4
# File #9577: Detected number: 4
# File #9578: Detected number: 1
# File #9579: Detected number: 7
# File #9580: Detected number: 1
# File #9581: Detected number: 8
# File #9582: Detected number: 9
# File #9583: Detected number: 0
# File #9584: Detected number: 5
# File #9585: Detected number: 5
# File #9586: Detected number: 6
# File #9587: Detected number: 0
# File #9588: Detected number: 5
# File #9589: Detected number: 3
# File #9590: Detected number: 9
# File #9591: Detected number: 8
# File #9592: Detected number: 8
# File #9593: Detected number: 9
# File #9594: Detected number: 9
# File #9595: Detected number: 4
# File #9596: Detected number: 2
# File #9597: Detected number: 0
# File #9598: Detected number: 7
# File #9599: Detected number: 7
# File #9600: Detected number: 9
# File #9601: Detected number: 1
# File #9602: Detected number: 6
# File #9603: Detected number: 0
# File #9604: Detected number: 4
# File #9605: Detected number: 0
# File #9606: Detected number: 1
# File #9607: Detected number: 4
# File #9608: Detected number: 3
# File #9609: Detected number: 0
# File #9610: Detected number: 9
# File #9611: Detected number: 2
# File #9612: Detected number: 7
# File #9613: Detected number: 6
# File #9614: Detected number: 0
# File #9615: Detected number: 0
# File #9616: Detected number: 3
# File #9617: Detected number: 7
# File #9618: Detected number: 8
# File #9619: Detected number: 7
# File #9620: Detected number: 0
# File #9621: Detected number: 2
# File #9622: Detected number: 3
# File #9623: Detected number: 2
# File #9624: Detected number: 5
# File #9625: Detected number: 5
# File #9626: Detected number: 5
# File #9627: Detected number: 4
# File #9628: Detected number: 9
# File #9629: Detected number: 5
# File #9630: Detected number: 4
# File #9631: Detected number: 4
# File #9632: Detected number: 4
# File #9633: Detected number: 2
# File #9634: Detected number: 5
# File #9635: Detected number: 3
# File #9636: Detected number: 2
# File #9637: Detected number: 5
# File #9638: Detected number: 6
# File #9639: Detected number: 8
# File #9640: Detected number: 7
# File #9641: Detected number: 8
# File #9642: Detected number: 2
# File #9643: Detected number: 8
# File #9644: Detected number: 4
# File #9645: Detected number: 7
# File #9646: Detected number: 6
# File #9647: Detected number: 6
# File #9648: Detected number: 6
# File #9649: Detected number: 7
# File #9650: Detected number: 1
# File #9651: Detected number: 1
# File #9652: Detected number: 3
# File #9653: Detected number: 4
# File #9654: Detected number: 9
# File #9655: Detected number: 3
# File #9656: Detected number: 8
# File #9657: Detected number: 9
# File #9658: Detected number: 7
# File #9659: Detected number: 4
# File #9660: Detected number: 2
# File #9661: Detected number: 8
# File #9662: Detected number: 5
# File #9663: Detected number: 4
# File #9664: Detected number: 9
# File #9665: Detected number: 3
# File #9666: Detected number: 0
# File #9667: Detected number: 1
# File #9668: Detected number: 6
# File #9669: Detected number: 4
# File #9670: Detected number: 8
# File #9671: Detected number: 3
# File #9672: Detected number: 3
# File #9673: Detected number: 5
# File #9674: Detected number: 9
# File #9675: Detected number: 8
# File #9676: Detected number: 9
# File #9677: Detected number: 3
# File #9678: Detected number: 6
# File #9679: Detected number: 5
# File #9680: Detected number: 3
# File #9681: Detected number: 8
# File #9682: Detected number: 1
# File #9683: Detected number: 1
# File #9684: Detected number: 8
# File #9685: Detected number: 1
# File #9686: Detected number: 0
# File #9687: Detected number: 7
# File #9688: Detected number: 5
# File #9689: Detected number: 3
# File #9690: Detected number: 7
# File #9691: Detected number: 8
# File #9692: Detected number: 0
# File #9693: Detected number: 9
# File #9694: Detected number: 1
# File #9695: Detected number: 3
# File #9696: Detected number: 8
# File #9697: Detected number: 2
# File #9698: Detected number: 0
# File #9699: Detected number: 1
# File #9700: Detected number: 2
# File #9701: Detected number: 4
# File #9702: Detected number: 3
# File #9703: Detected number: 3
# File #9704: Detected number: 9
# File #9705: Detected number: 4
# File #9706: Detected number: 2
# File #9707: Detected number: 0
# File #9708: Detected number: 7
# File #9709: Detected number: 2
# File #9710: Detected number: 2
# File #9711: Detected number: 4
# File #9712: Detected number: 0
# File #9713: Detected number: 3
# File #9714: Detected number: 1
# File #9715: Detected number: 7
# File #9716: Detected number: 8
# File #9717: Detected number: 7
# File #9718: Detected number: 3
# File #9719: Detected number: 7
# File #9720: Detected number: 7
# File #9721: Detected number: 0
# File #9722: Detected number: 3
# File #9723: Detected number: 5
# File #9724: Detected number: 7
# File #9725: Detected number: 5
# File #9726: Detected number: 1
# File #9727: Detected number: 9
# File #9728: Detected number: 1
# File #9729: Detected number: 6
# File #9730: Detected number: 8
# File #9731: Detected number: 3
# File #9732: Detected number: 5
# File #9733: Detected number: 2
# File #9734: Detected number: 8
# File #9735: Detected number: 7
# File #9736: Detected number: 2
# File #9737: Detected number: 5
# File #9738: Detected number: 3
# File #9739: Detected number: 5
# File #9740: Detected number: 8
# File #9741: Detected number: 0
# File #9742: Detected number: 5
# File #9743: Detected number: 9
# File #9744: Detected number: 9
# File #9745: Detected number: 3
# File #9746: Detected number: 7
# File #9747: Detected number: 0
# File #9748: Detected number: 6
# File #9749: Detected number: 8
# File #9750: Detected number: 7
# File #9751: Detected number: 6
# File #9752: Detected number: 1
# File #9753: Detected number: 0
# File #9754: Detected number: 2
# File #9755: Detected number: 3
# File #9756: Detected number: 3
# File #9757: Detected number: 9
# File #9758: Detected number: 6
# File #9759: Detected number: 6
# File #9760: Detected number: 5
# File #9761: Detected number: 0
# File #9762: Detected number: 0
# File #9763: Detected number: 8
# File #9764: Detected number: 2
# File #9765: Detected number: 5
# File #9766: Detected number: 7
# File #9767: Detected number: 2
# File #9768: Detected number: 8
# File #9769: Detected number: 2
# File #9770: Detected number: 7
# File #9771: Detected number: 7
# File #9772: Detected number: 9
# File #9773: Detected number: 7
# File #9774: Detected number: 2
# File #9775: Detected number: 9
# File #9776: Detected number: 4
# File #9777: Detected number: 8
# File #9778: Detected number: 9
# File #9779: Detected number: 6
# File #9780: Detected number: 9
# File #9781: Detected number: 6
# File #9782: Detected number: 7
# File #9783: Detected number: 5
# File #9784: Detected number: 1
# File #9785: Detected number: 2
# File #9786: Detected number: 3
# File #9787: Detected number: 9
# File #9788: Detected number: 9
# File #9789: Detected number: 9
# File #9790: Detected number: 0
# File #9791: Detected number: 2
# File #9792: Detected number: 1
# File #9793: Detected number: 7
# File #9794: Detected number: 0
# File #9795: Detected number: 0
# File #9796: Detected number: 0
# File #9797: Detected number: 7
# File #9798: Detected number: 7
# File #9799: Detected number: 1
# File #9800: Detected number: 6
# File #9801: Detected number: 7
# File #9802: Detected number: 7
# File #9803: Detected number: 0
# File #9804: Detected number: 2
# File #9805: Detected number: 6
# File #9806: Detected number: 4
# File #9807: Detected number: 7
# File #9808: Detected number: 3
# File #9809: Detected number: 5
# File #9810: Detected number: 5
# File #9811: Detected number: 1
# File #9812: Detected number: 1
# File #9813: Detected number: 5
# File #9814: Detected number: 7
# File #9815: Detected number: 3
# File #9816: Detected number: 9
# File #9817: Detected number: 7
# File #9818: Detected number: 7
# File #9819: Detected number: 7
# File #9820: Detected number: 7
# File #9821: Detected number: 7
# File #9822: Detected number: 8
# File #9823: Detected number: 9
# File #9824: Detected number: 4
# File #9825: Detected number: 6
# File #9826: Detected number: 1
# File #9827: Detected number: 4
# File #9828: Detected number: 1
# File #9829: Detected number: 8
# File #9830: Detected number: 9
# File #9831: Detected number: 1
# File #9832: Detected number: 0
# File #9833: Detected number: 3
# File #9834: Detected number: 2
# File #9835: Detected number: 7
# File #9836: Detected number: 5
# File #9837: Detected number: 0
# File #9838: Detected number: 1
# File #9839: Detected number: 7
# File #9840: Detected number: 2
# File #9841: Detected number: 7
# File #9842: Detected number: 7
# File #9843: Detected number: 1
# File #9844: Detected number: 7
# File #9845: Detected number: 4
# File #9846: Detected number: 5
# File #9847: Detected number: 2
# File #9848: Detected number: 8
# File #9849: Detected number: 6
# File #9850: Detected number: 3
# File #9851: Detected number: 2
# File #9852: Detected number: 9
# File #9853: Detected number: 2
# File #9854: Detected number: 0
# File #9855: Detected number: 2
# File #9856: Detected number: 5
# File #9857: Detected number: 9
# File #9858: Detected number: 6
# File #9859: Detected number: 7
# File #9860: Detected number: 6
# File #9861: Detected number: 1
# File #9862: Detected number: 3
# File #9863: Detected number: 6
# File #9864: Detected number: 3
# File #9865: Detected number: 6
# File #9866: Detected number: 8
# File #9867: Detected number: 3
# File #9868: Detected number: 8
# File #9869: Detected number: 0
# File #9870: Detected number: 5
# File #9871: Detected number: 0
# File #9872: Detected number: 8
# File #9873: Detected number: 9
# File #9874: Detected number: 3
# File #9875: Detected number: 2
# File #9876: Detected number: 6
# File #9877: Detected number: 6
# File #9878: Detected number: 0
# File #9879: Detected number: 3
# File #9880: Detected number: 1
# File #9881: Detected number: 7
# File #9882: Detected number: 4
# File #9883: Detected number: 3
# File #9884: Detected number: 6
# File #9885: Detected number: 0
# File #9886: Detected number: 9
# File #9887: Detected number: 5
# File #9888: Detected number: 6
# File #9889: Detected number: 8
# File #9890: Detected number: 7
# File #9891: Detected number: 8
# File #9892: Detected number: 8
# File #9893: Detected number: 6
# File #9894: Detected number: 3
# File #9895: Detected number: 3
# File #9896: Detected number: 0
# File #9897: Detected number: 1
# File #9898: Detected number: 3
# File #9899: Detected number: 7
# File #9900: Detected number: 8
# File #9901: Detected number: 6
# File #9902: Detected number: 4
# File #9903: Detected number: 4
# File #9904: Detected number: 9
# File #9905: Detected number: 6
# File #9906: Detected number: 7
# File #9907: Detected number: 3
# File #9908: Detected number: 9
# File #9909: Detected number: 0
# File #9910: Detected number: 9
# File #9911: Detected number: 0
# File #9912: Detected number: 6
# File #9913: Detected number: 2
# File #9914: Detected number: 6
# File #9915: Detected number: 1
# File #9916: Detected number: 2
# File #9917: Detected number: 7
# File #9918: Detected number: 9
# File #9919: Detected number: 4
# File #9920: Detected number: 9
# File #9921: Detected number: 2
# File #9922: Detected number: 5
# File #9923: Detected number: 1
# File #9924: Detected number: 3
# File #9925: Detected number: 8
# File #9926: Detected number: 7
# File #9927: Detected number: 3
# File #9928: Detected number: 9
# File #9929: Detected number: 7
# File #9930: Detected number: 3
# File #9931: Detected number: 6
# File #9932: Detected number: 8
# File #9933: Detected number: 7
# File #9934: Detected number: 5
# File #9935: Detected number: 6
# File #9936: Detected number: 0
# File #9937: Detected number: 6
# File #9938: Detected number: 1
# File #9939: Detected number: 9
# File #9940: Detected number: 9
# File #9941: Detected number: 6
# File #9942: Detected number: 0
# File #9943: Detected number: 4
# File #9944: Detected number: 4
# File #9945: Detected number: 6
# File #9946: Detected number: 2
# File #9947: Detected number: 7
# File #9948: Detected number: 1
# File #9949: Detected number: 6
# File #9950: Detected number: 2
# File #9951: Detected number: 7
# File #9952: Detected number: 2
# File #9953: Detected number: 2
# File #9954: Detected number: 6
# File #9955: Detected number: 3
# File #9956: Detected number: 2
# File #9957: Detected number: 6
# File #9958: Detected number: 4
# File #9959: Detected number: 1
# File #9960: Detected number: 5
# File #9961: Detected number: 0
# File #9962: Detected number: 0
# File #9963: Detected number: 8
# File #9964: Detected number: 1
# File #9965: Detected number: 7
# File #9966: Detected number: 2
# File #9967: Detected number: 1
# File #9968: Detected number: 4
# File #9969: Detected number: 5
# File #9970: Detected number: 3
# File #9971: Detected number: 1
# File #9972: Detected number: 6
# File #9973: Detected number: 0
# File #9974: Detected number: 1
# File #9975: Detected number: 0
# File #9976: Detected number: 4
# File #9977: Detected number: 1
# File #9978: Detected number: 9
# File #9979: Detected number: 6
# File #9980: Detected number: 8
# File #9981: Detected number: 8
# File #9982: Detected number: 4
# File #9983: Detected number: 1
# File #9984: Detected number: 4
# File #9985: Detected number: 9
# File #9986: Detected number: 0
# File #9987: Detected number: 4
# File #9988: Detected number: 1
# File #9989: Detected number: 4
# File #9990: Detected number: 3
# File #9991: Detected number: 3
# File #9992: Detected number: 4
# File #9993: Detected number: 5
# File #9994: Detected number: 0
# File #9995: Detected number: 0
# File #9996: Detected number: 2
# File #9997: Detected number: 9
# File #9998: Detected number: 1
# File #9999: Detected number: 8
# File #10000: Detected number: 7
# Connection with ('10.21.236.238', 37430) closed.
# Total Time Taken So Far: 21.92 seconds

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np
import socket
import os
import time

# Load the bitstream
overlay = Overlay("one.bit")

dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Socket setup
HOST = "0.0.0.0"  # Listen on all interfaces
PORT = 9092       # Port number

total_time = 0  # Initialize total time

def process_file(conn, addr):
    """Process a single file received from the client."""
    global total_time  # Declare total_time as global to modify it

    print(f"Connected by {addr}")
    try:
        while True:
            # Receive 784 bytes of pixel data
            data = conn.recv(784)
            
            # Convert the received bytes to a NumPy array
            pixel_data = np.frombuffer(data, dtype=np.uint8)
            
            # Measure start time
            

            # Allocate input buffer and copy data
            input_buffer = allocate(shape=(784,), dtype=np.uint8)
            np.copyto(input_buffer, pixel_data)

            start_time = time.time()
            
            # Send data to FPGA for processing
            dma.sendchannel.transfer(input_buffer)
#             dma.sendchannel.wait()

            # Read the result directly from the zyNet IP
            result_offset = 8  # Adjust based on your IP core
            detected_digit = zynet.read(result_offset)

            # Measure end time and accumulate duration
            end_time = time.time()
            
            total_time += (end_time - start_time)
            
            # Validate and send the result back to the client
            if 0 <= detected_digit <= 9:  # Assuming valid digits are 0-9
                conn.sendall(bytes([detected_digit]))
                print(f"Processed and sent predicted number: {detected_digit}")
            else:
                print(f"Invalid result from FPGA: {detected_digit}.")
                conn.sendall(b'\xFF')  # Send error code
    except Exception as e:
        print(f"Error processing file from {addr}: {e}")
    finally:
        conn.close()
        print(f"Connection with {addr} closed.")

# Main server loop
with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
    s.bind((HOST, PORT))
    s.listen()
    print(f"Server listening on {HOST}:{PORT}...")

    while True:
        conn, addr = s.accept()
        process_file(conn, addr)
        print(f"Total Time Taken So Far: {total_time:.2f} seconds")

# %%
import socket
from pynq import Overlay
from pynq import allocate
import numpy as np

# Load the overlay
overlay = Overlay("one.bit")

# Access DMA and custom IP
dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Server setup
host = '0.0.0.0'  # Listen on all available interfaces
port = 9092

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.bind((host, port))
server_socket.listen(1)  # Listen for one connection at a time
print(f"Server listening on {host}:{port}")

while True:
    print("Waiting for a connection...")
    conn, addr = server_socket.accept()
    print(f"Connected by {addr}")

    try:
        # Receive the label (8 bits)
        label_binary = conn.recv(8).decode()
        print(label_binary)
        print(1)
        if not label_binary:
            print("No label received.")
            conn.close()
            continue
        expected_label = int(label_binary, 2)  # Convert binary to integer
        print(expected_label)
#         # Receive the pixel data (784 * 8 bits)
        pixel_binary = b''
        expected_size = 784 * 8  # 784 pixels, each 8 bits
        chunk_size = 128  # Receive data in chunks
#         while len(pixel_binary) < expected_size:
#             packet = conn.recv(chunk_size)
#             if not packet:
#                 break
#             pixel_binary += packet

#         if len(pixel_binary) < expected_size:
#             print("Incomplete pixel data received. Closing connection.")
#             conn.close()
#             continue

#         # Convert the binary data back to pixel values
#         pixel_data = np.array([
#             int(pixel_binary[i:i+8], 2)
#             for i in range(0, len(pixel_binary), 8)
#         ], dtype=np.uint8)

#         # Allocate input buffer for DMA
#         input_buffer = allocate(shape=(784,), dtype=np.uint8)
#         np.copyto(input_buffer, pixel_data)

#         # Transfer data to the FPGA using DMA
#         dma.sendchannel.transfer(input_buffer)
#         dma.sendchannel.wait()

#         # Read the result directly from the zyNet IP
#         result_offset = 8  # Offset for the detected digit
#         detected_digit = zynet.read(result_offset)

#         # Log the results
#         print(f"Label: {expected_label}, Predicted: {detected_digit}")
#         print("Result: Correct" if detected_digit == expected_label else "Result: Incorrect")

        # Send the detected digit back to the client as an 8-bit binary
        detected_binary = format(2, '08b')
        conn.sendall(detected_binary.encode())

    except Exception as e:
        print(f"Error occurred: {e}")
    finally:
        conn.close()
        print("Connection closed.")
# Out:
# Server listening on 0.0.0.0:9092
# Waiting for a connection...
# Connected by ('10.21.236.238', 50546)
# 01101111
# Connection closed.
# Waiting for a connection...
# Connected by ('10.21.236.238', 44268)
# 01101111
# Connection closed.
# Waiting for a connection...
# Connected by ('10.21.236.238', 36998)
# 01101111
# Connection closed.
# Waiting for a connection...
# Connected by ('10.21.236.238', 58354)
# 01101111
# Connection closed.
# Waiting for a connection...

# %%
import socket
import numpy as np
from pynq import Overlay
from pynq.lib.dma import DMA
from pynq import allocate
import time

# Load the FPGA overlay and configure DMA
overlay = Overlay("one.bit")  # Updated overlay for MNIST processing
dma = overlay.axi_dma_0

# Create a server socket
server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.bind(('0.0.0.0', 9092))  # Bind to all available interfaces on port 9092
server_socket.listen(1)  # Listen for one connection at a time

print("Waiting for a connection...")
conn, addr = server_socket.accept()  # Accept a connection from a client
print(f"Connected by {addr}")

# Initialize performance measurement variables
num_images_processed = 0
total_fpga_processing_time = 0

# Start timer for overall processing
overall_start_time = time.time()

try:
    while True:
        # Receive the image dimensions (should be 28x28x1 for MNIST)
        image_info = conn.recv(1024).decode()
        if not image_info:
            break  # Exit if no data is received

        # Parse image dimensions
        try:
            height, width, channels = map(int, image_info.split(','))
            if height != 28 or width != 28 or channels != 1:
                print(f"Invalid MNIST dimensions received: {image_info}")
                continue
        except ValueError as e:
            print(f"Invalid image dimensions received: {image_info}")
            continue

        # Allocate buffers for input and output
        try:
            input_buffer = allocate(shape=(28 * 28,), dtype=np.uint8)  # Flattened 28x28 image
            output_buffer = allocate(shape=(1,), dtype=np.uint8)  # Single-byte output for the predicted digit
        except RuntimeError as e:
            print(f"Memory allocation failed: {e}")
            continue

        # Receive the image bytes (28x28 grayscale pixel values)
        image_bytes = b''
        while len(image_bytes) < 28 * 28:
            packet = conn.recv(4096)
            if not packet:
                break
            image_bytes += packet

        # Copy image bytes to the input buffer
        np.copyto(input_buffer, np.frombuffer(image_bytes, dtype=np.uint8))

        # Send the input buffer to the FPGA for processing
        dma.sendchannel.transfer(input_buffer)
        dma.recvchannel.transfer(output_buffer)

        # Wait for transfer to complete
        dma.sendchannel.wait()
        dma.recvchannel.wait()

        # Retrieve the predicted digit from the output buffer
        predicted_digit = int(output_buffer[0])

        # Send the predicted digit back to the client
        conn.sendall(bytes([predicted_digit]))

        # Increment the processed image count
        num_images_processed += 1

    # End the timer and calculate the total FPGA processing time
    overall_end_time = time.time()
    total_fpga_processing_time = overall_end_time - overall_start_time

    # Calculate throughput
    if num_images_processed > 0:
        throughput = num_images_processed / total_fpga_processing_time
        print(f"Total images processed: {num_images_processed}")
        print(f"Total FPGA processing time: {total_fpga_processing_time:.6f} seconds")
        print(f"Throughput: {throughput:.2f} images per second")
    else:
        print("No images were processed.")

finally:
    # Close connections
    conn.close()
    server_socket.close()

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np
import time

# Load the overlay (bitstream)
overlay = Overlay("one.bit")  # Replace "zynq_nn.bit" with your bitstream filename
dma = overlay.axi_dma_0  # Replace with your actual DMA IP name

# Base address of the custom logic
zynet_base_addr = overlay.ip_dict['zynet_0']['phys_addr']  # Replace 'zynet_0' with your IP name

# Input data and expected result
input_data = np.array(dataValues, dtype=np.uint8)  # Load or define your 28x28 input data as 'dataValues'
expected_result = result  # Replace 'result' with the expected output

# Allocate buffers for DMA
input_buffer = allocate(shape=(28*28,), dtype=np.uint8)
output_buffer = allocate(shape=(1,), dtype=np.uint32)  # Buffer for output

# Copy input data into the input buffer
np.copyto(input_buffer, input_data.flatten())

# Initialize the DMA transfer
dma.sendchannel.transfer(input_buffer)  # Transfer input data to the custom logic
dma.recvchannel.transfer(output_buffer)  # Receive the output from the custom logic

# Wait for the transfer to complete
dma.sendchannel.wait()
dma.recvchannel.wait()

# Retrieve the result
detected_digit = output_buffer[0]

# Compare with the expected result
print(f"Detected number: {detected_digit}, Expected number: {expected_result}")

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np
import time

# Load the overlay
overlay = Overlay("one.bit")  # Replace with your bitstream file name

# Get peripherals
dma = overlay.axi_dma_0  # Replace 'axi_dma_0' with the actual DMA IP name in your design
zynet = overlay.zyNet_0  # Replace 'zyNet_0' with the actual IP name for the zyNet custom peripheral

#

# %%
#  Base address and offsets for custom IP (zyNet)
zynet_base_addr = overlay.ip_dict['zyNet_0']['phys_addr']  # Replace 'zyNet_0' with the actual name
interrupt_clear_offset = 24  # Replace with the correct offset for clearing the interrupt
result_offset = 8  # Replace with the correct offset for reading the result

# Data input and expected result
dataValues = np.random.randint(0, 256, (28, 28), dtype=np.uint8)  # Example 28x28 data
result = 5  # Replace with the expected digit

# Allocate buffers
input_buffer = allocate(shape=(28 * 28,), dtype=np.uint8)  # Flatten 28x28 input data
output_buffer = allocate(shape=(1,), dtype=np.uint32)  # Single value for the output

# Copy input data to buffer
np.copyto(input_buffer, dataValues.flatten())

# %%
# Initialize the DMA
dma.sendchannel.transfer(input_buffer)  # Transfer input data to custom IP
dma.recvchannel.transfer(output_buffer)  # Prepare buffer to receive the result

# Start processing
print("Processing data...")
dma.sendchannel.wait()
dma.recvchannel.wait()

# Read the result
detected_digit = output_buffer[0]

# Display results
print(f"Detected number: {detected_digit}")
print(f"Expected number: {result}")

# Check the result
if detected_digit == result:
    print("Test passed!")
else:
    print("Test failed!")

# Clear interrupt (if applicable)
zynet.write(interrupt_clear_offset, 0x1)  # Replace with the actual method for clearing the interrupt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 # Initialize the DMA
#       2 dma.sendchannel.transfer(input_buffer)  # Transfer input data to custom IP
# ----> 3 dma.recvchannel.transfer(output_buffer)  # Prepare buffer to receive the result
#       5 # Start processing
#       6 print("Processing data...")
#
# AttributeError: 'NoneType' object has no attribute 'transfer'

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np

# Load the overlay
overlay = Overlay("one.bit")

# Get peripherals
dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Input data and expected result
# dataValues = np.random.randint(0, 256, (28, 28), dtype=np.uint8)  # Example 28x28 data

input_file = "test_data_0000.txt"  # Replace with the actual path to your one.txt file
with open(input_file, "r") as file:
    binary_data = file.read().splitlines()  # Read each line as a string

# Convert binary strings to integers
input_buffer = np.array([int(b, 2) for b in binary_data], dtype=np.uint8)


result = 5  # Replace with the expected digit

# Allocate input buffer
input_buffer = allocate(shape=(28 * 28,), dtype=np.uint8)
np.copyto(input_buffer, dataValues.flatten())

# Transfer input data to custom IP
dma.sendchannel.transfer(input_buffer)
dma.sendchannel.wait()

# Read the result directly from the zyNet IP
zynet_base_addr = overlay.ip_dict['zyNet_0']['phys_addr']
result_offset = 8  # Replace with the correct offset
detected_digit = zynet.read(result_offset)

# Display results
print(f"Detected number: {detected_digit}")
print(f"Expected number: {result}")
# Out:
# Detected number: 1
# Expected number: 5

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np

# Load the overlay
overlay = Overlay("one.bit")

# Get peripherals
dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Input data and expected result
# dataValues = np.random.randint(0, 256, (28, 28), dtype=np.uint8)  # Example 28x28 data

input_file = "test_data_0009.txt"  # Replace with the actual path to your one.txt file
with open(input_file, "r") as file:
    binary_data = file.read().splitlines()  # Read each line as a string

# Convert binary strings to integers
dataValues = np.array([int(b, 2) for b in binary_data], dtype=np.uint8)


result = 5  # Replace with the expected digit

# Allocate input buffer
input_buffer = allocate(shape=(28 * 28,), dtype=np.uint8)
np.copyto(input_buffer, dataValues.flatten())

# Transfer input data to custom IP
dma.sendchannel.transfer(input_buffer)
dma.sendchannel.wait()

# Read the result directly from the zyNet IP
zynet_base_addr = overlay.ip_dict['zyNet_0']['phys_addr']
result_offset = 8  # Replace with the correct offset
detected_digit = zynet.read(result_offset)

# Display results
print(f"Detected number: {detected_digit}")
print(f"Expected number: {result}")
# Out:
# Detected number: 9
# Expected number: 5

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np

# Load the overlay
overlay = Overlay("one.bit")  # Replace with your actual bitstream filename

# Get peripherals
dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

# Input file with 785 numbers
input_file = "test_data_0000.txt"  # Replace with the actual path to your input file
with open(input_file, "r") as file:
    binary_data = file.read().splitlines()  # Read each line as a string

# Convert binary strings to integers
data = np.array([int(b, 2) for b in binary_data], dtype=np.uint8)

# Separate pixel data and expected result
pixel_data = data[:784]  # First 784 numbers are pixel values
expected_result = data[784]  # 785th number is the expected output

# Allocate input buffer
input_buffer = allocate(shape=(784,), dtype=np.uint8)
np.copyto(input_buffer, pixel_data.flatten())

# Transfer input data to custom IP
dma.sendchannel.transfer(input_buffer)
dma.sendchannel.wait()

# Read the result directly from the zyNet IP
zynet_base_addr = overlay.ip_dict['zyNet_0']['phys_addr']
result_offset = 8  # Replace with the correct offset
detected_digit = zynet.read(result_offset)

# Display results
print(f"Detected number: {detected_digit}")
print(f"Expected number: {expected_result}")
# Out:
# Detected number: 7
# Expected number: 7

# %%
from pynq import Overlay
from pynq import allocate
import numpy as np

overlay = Overlay("one.bit") 

dma = overlay.axi_dma_0
zynet = overlay.zyNet_0

file_template = "test_data_{:04d}.txt" 

# Process 10 files
for i in range(10):
    input_file = file_template.format(i)
    print(f"Processing file: {input_file}")

    with open(input_file, "r") as file:
        binary_data = file.read().splitlines()  # Read each line as a string

    data = np.array([int(b, 2) for b in binary_data], dtype=np.uint8)     # Convert binary strings to integers

    pixel_data = data[:784]  # First 784 numbers are pixel values
    expected_result = data[784]  # 785th number is the expected output

    input_buffer = allocate(shape=(784,), dtype=np.uint8)
    np.copyto(input_buffer, pixel_data.flatten())

    dma.sendchannel.transfer(input_buffer)
    dma.sendchannel.wait()

    # Read the result directly from the zyNet IP
    zynet_base_addr = overlay.ip_dict['zyNet_0']['phys_addr']
    result_offset = 8
    detected_digit = zynet.read(result_offset)

    print(f"Detected number: {detected_digit}")
    print(f"Expected number: {expected_result}")
# Out:
# Processing file: test_data_0000.txt
# Detected number: 7
# Expected number: 7
# Processing file: test_data_0001.txt
# Detected number: 2
# Expected number: 2
# Processing file: test_data_0002.txt
# Detected number: 1
# Expected number: 1
# Processing file: test_data_0003.txt
# Detected number: 0
# Expected number: 0
# Processing file: test_data_0004.txt
# Detected number: 4
# Expected number: 4
# Processing file: test_data_0005.txt
# Detected number: 1
# Expected number: 1
# Processing file: test_data_0006.txt
# Detected number: 4
# Expected number: 4
# Processing file: test_data_0007.txt
# Detected number: 9
# Expected number: 9
# Processing file: test_data_0008.txt
# Detected number: 6
# Expected number: 5
# Processing file: test_data_0009.txt
# Detected number: 9
# Expected number: 9
